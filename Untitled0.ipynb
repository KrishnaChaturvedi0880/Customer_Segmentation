# %% [markdown]
# Installing Dependencies

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn scipy

# %% [markdown]
# Loading the Data

# %%
import pandas as pd
data = pd.read_csv('Mall_Customers.csv')
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# Handle Missing Values

# %%
data = data.dropna()

# %% [markdown]
# Feature Selection

# %%
features = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]

# %% [markdown]
# Normalization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# %% [markdown]
# Vizualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(data[['Age','Annual Income (k$)','Spending Score (1-100)']])
plt.show()

# %% [markdown]
# K-Means Clustering

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range (1,11):
  kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init = 10, random_state = 0)
  kmeans.fit(features_scaled)
  wcss.append(kmeans.inertia_)

#Plotting the Elbow Method
plt.plot(range(1,11),wcss)
plt.title('Elbow Method')
plt.xlabel('Number Of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# Training the K Menas Model

# %%
optimal_k = 5
kmeans = KMeans(n_clusters=optimal_k, init ='k-means++', max_iter=300, n_init=10, random_state=0)
y_kmeans = kmeans.fit_predict(features_scaled)

# %% [markdown]
# Visualization Of Clusters

# %%
plt.scatter(features_scaled[y_kmeans == 0, 0], features_scaled[y_kmeans == 0, 1], s=100, c='red', label='Cluster 1')
plt.scatter(features_scaled[y_kmeans == 1, 0], features_scaled[y_kmeans == 1, 1], s=100, c='blue', label='Cluster 2')
plt.scatter(features_scaled[y_kmeans == 2, 0], features_scaled[y_kmeans == 2, 1], s=100, c='green', label='Cluster 3')
plt.scatter(features_scaled[y_kmeans == 3, 0], features_scaled[y_kmeans == 3, 1], s=100, c='cyan', label='Cluster 4')
plt.scatter(features_scaled[y_kmeans == 4, 0], features_scaled[y_kmeans == 4, 1], s=100, c='magenta', label='Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='yellow', label='Centroids')
plt.title('Customer Segments')
plt.xlabel('Annual Income (scaled)')
plt.ylabel('Spending Score (scaled)')
plt.legend()
plt.show()

# %% [markdown]
# Analyzation of Segments

# %%
data['Cluster'] = y_kmeans

numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns

cluster_summary = data.groupby('Cluster')[numeric_columns].mean()
print(cluster_summary)
# Out:
#          CustomerID        Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0         83.872340  55.638298           54.382979               48.851064
# 1        159.743590  39.871795           86.102564               19.358974
# 2        161.025000  32.875000           86.100000               81.525000
# 3         24.100000  46.250000           26.750000               18.350000
# 4         55.648148  25.185185           41.092593               62.240741

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(features_scaled, y_kmeans)
print(f"Silhouette Score: {score}")
# Out:
# Silhouette Score: 0.41664341513732767
